# %%
import pandas as pd
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('totol_2output.csv')
x = df.iloc[:, 1:20]
y = df.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
clf = SVC(kernel='poly', gamma='auto', C=1.0, degree=1)
clf.fit(x_train, y_train)
score = clf.score(x_test, y_test)

print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.252341272767495
# <class 'numpy.float64'>

# %%
df = pd.read_csv('totol_2output.csv')
x = df.iloc[:, 1:20]
y = df.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
clf = SVC(kernel='linear', gamma='auto', C=1.0)
clf.fit(x_train, y_train)
score = clf.score(x_test, y_test)

print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.7849716097632918
# <class 'numpy.float64'>

# %%
# SVC RBF
df = pd.read_csv('totol_2output.csv')
x = df.iloc[:, 1:20]
y = df.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
clf = SVC(kernel='rbf', gamma='auto', C=1.0)
clf.fit(x_train, y_train)
score = clf.score(x_test, y_test)

print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.721406975886734
# <class 'numpy.float64'>

# %%
df = pd.read_csv('totol_2output.csv')
x = df.iloc[:, 1:]
y = df.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
clf = SVC(kernel='linear', gamma='scale', C=1.0)
clf.fit(x_train, y_train)
score = clf.score(x_test, y_test)

print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.8504535063785856
# <class 'numpy.float64'>

# %%
df = pd.read_csv('outputnew2.csv')
x = df.iloc[:, 1:]
y = df.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
clf = SVC(kernel='rbf', gamma=1, C=0.1)
clf.fit(x_train, y_train)
score = clf.score(x_test, y_test)
print("準確率:{}".format(score))
df_test = pd.read_csv('output0_2.csv')
x = df_test.iloc[:, 1:]
y = df_test.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.5)
score = clf.score(x_test, y_test)
print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.9144486692015209
# 準確率:0.4605087014725569
# <class 'numpy.float64'>

# %%
df = pd.read_csv('output5.csv')
x = df.iloc[:, 1:]
y = df.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
clf = SVC(kernel='linear', gamma='auto', C=1.0)
clf.fit(x_train, y_train)
score = clf.score(x_test, y_test)
print("準確率:{}".format(score))
df_test = pd.read_csv('outputpic0.csv')
x_test = df_test.iloc[:, 1:]
y_test = df_test.iloc[:, 0]
score = clf.score(x_test, y_test)
print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.8416783423051397
# 準確率:0.4869215291750503
# <class 'numpy.float64'>

# %%
df = pd.read_csv("outputtotal2_3fps.csv", header=0)
df2 = pd.read_csv("fps_Vec_1220.csv", header=0)
df = pd.concat([df, df2], ignore_index=True)
x = df.iloc[:, 1:]
y = df.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
clf = SVC(kernel='rbf', gamma=1, C=2)
clf.fit(x_train, y_train)
score = clf.score(x_test, y_test)
print("準確率:{}".format(score))
df_test = pd.read_csv('fps_Vec_1220_test.csv')
x_test = df_test.iloc[:, 1:]
y_test = df_test.iloc[:, 0]
score = clf.score(x_test, y_test)
print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.8597997138769671
# 準確率:0.8252840909090909
# <class 'numpy.float64'>

# %%
df = pd.read_csv('outputtotal2_3fps.csv')
df2 = pd.read_csv('outputnew1_2fps.csv')
df = pd.concat([df, df2])
x = df.iloc[:, 1:]
y = df.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
clf = SVC(kernel='rbf', gamma=3, C=3.1)
clf.fit(x_train, y_train)
score = clf.score(x_test, y_test)
print("準確率:{}".format(score))
df_test = pd.read_csv('output0_2.csv')
x_test = df_test.iloc[:, 1:]
y_test = df_test.iloc[:, 0]
score = clf.score(x_test, y_test)

print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.9120956399437412
# 準確率:0.7831325301204819
# <class 'numpy.float64'>

# %%
df = pd.read_csv('outputnew0.csv')
df2 = pd.read_csv('outputnew2.csv')
df2 = df2.iloc[:, 1:]
df = pd.concat([df, df2], axis=1)
x = df.iloc[:, 1:]
y = df.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
clf = SVC(kernel='rbf', gamma=0.1, C=0.1)
clf.fit(x_train, y_train)
score = clf.score(x_test, y_test)
print("準確率:{}".format(score))
df_test = pd.read_csv('outputpic0.csv')
df_test2 = pd.read_csv('output_pic2.csv')
df_test2 = df_test2.iloc[:,1:]
df_test = pd.concat([df_test, df_test2], axis=1)
x_test = df_test.iloc[:, 1:]
y_test = df_test.iloc[:, 0]
score = clf.score(x_test, y_test)

print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.8472448548494176
# 準確率:0.4969818913480885
# <class 'numpy.float64'>

# %%
df_test = pd.read_csv('output0_2.csv')
x_test = df_test.iloc[:, 1:]
y_test = df_test.iloc[:, 0]
score = clf.score(x_test, y_test)

print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.7694109772423026
# <class 'numpy.float64'>

# %%
df_test = pd.read_csv('output_pic2.csv')
x_test = df_test.iloc[:, 1:]
y_test = df_test.iloc[:, 0]
score = clf.score(x_test, y_test)

print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.26961770623742454
# <class 'numpy.float64'>

# %%
df2 = pd.read_csv('outputnew2.csv')
df2 = df2.iloc[:, 1:]
df2
# Out:
#        thumb_CmcX  thumb_CmcY  thumb_CmcZ  thumb_McpX  thumb_McpY  thumb_McpZ  \
# 0       -0.037934   -0.135734   -0.029992   -0.131812   -0.103565   -0.035802
# 1       -0.050843   -0.132324   -0.024386   -0.149042   -0.087836   -0.034627
# 2       -0.075088   -0.121743   -0.000038   -0.143827   -0.077398   -0.032715
# 3       -0.079474   -0.114379    0.009991   -0.129857   -0.075156   -0.029720
# 4       -0.079029   -0.118981    0.008975   -0.133592   -0.075965   -0.031504
# ...           ...         ...         ...         ...         ...         ...
# 55222    0.072328    0.009161   -0.132666    0.125427    0.014323   -0.035111
# 55223    0.069143    0.012992   -0.135617    0.118613    0.014051   -0.032920
# 55224    0.063458    0.018706   -0.133317    0.121509    0.016637   -0.033870
# 55225    0.071033    0.010048   -0.124296    0.124454    0.014671   -0.026412
# 55226    0.073547    0.004901   -0.115325    0.125164    0.015489   -0.023580
#
# ...

# %%
df = pd.read_csv('outputnew1.csv')
df2 = pd.read_csv('outputnew2.csv')
df2 = df2.iloc[:, 1:]
df = pd.concat([df, df2], axis=1)
df
# Out:
#   Cell In[4], line 10
#     y_test = df_test.iloc[:, 0]df
#                                ^
# SyntaxError: invalid syntax

# %%
df_test = pd.read_csv('output0_1.csv')
df_test2 = pd.read_csv('output0_2.csv')
df_test2 = df_test2.iloc[:,1:]
df_test = pd.concat([df_test, df_test2], axis=1)
x_test = df_test.iloc[:, 1:]
y_test = df_test.iloc[:, 0]
df_test
# Out:
#       class  thumb_CmcX  thumb_CmcY  thumb_CmcZ  thumb_McpX  thumb_McpY  \
# 0         2    0.078050    0.052410   -0.097754    0.175706    0.077343
# 1         2    0.065548    0.044494   -0.109377    0.152814    0.066387
# 2         2    0.054802    0.043668   -0.123050    0.141169    0.065330
# 3         2    0.050925    0.039249   -0.131191    0.133983    0.059390
# 4         2    0.047494    0.041844   -0.141178    0.128012    0.061758
# ...     ...         ...         ...         ...         ...         ...
# 2983      4   -0.113569   -0.080209   -0.047969   -0.222618   -0.130686
# 2984      4   -0.104551   -0.077983   -0.050287   -0.214026   -0.126151
# 2985      4   -0.104104   -0.077442   -0.058602   -0.216384   -0.128589
# 2986      4   -0.108454   -0.078550   -0.045807   -0.218662   -0.124936
# 2987      4   -0.106140   -0.080405   -0.049811   -0.217258   -0.131111
#
#       thumb_McpZ  thumb_IpX  thumb_IpY  thumb_IpZ  ...  pinky_McpZ  \
# ...

# %%
df = pd.read_csv('outputnew1.csv')
df2 = pd.read_csv('outputnew2.csv')
df2 = df2.iloc[:, 1:]
df = pd.concat([df, df2], axis=1)
x = df.iloc[:, 1:]
y = df.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.5)

clf = SVC(kernel='linear', gamma='auto', C=0.1)
clf.fit(x_train, y_train)
score = clf.score(x_test, y_test)
print("準確率:{}".format(score))

x_test = df_test.iloc[:10000, 1:]
y_test = df_test.iloc[:10000, 0]
score = clf.score(x_test, y_test)

print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.8615901653842752
# 準確率:0.4124748490945674
# <class 'numpy.float64'>

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#KNeighborsClassifier
df = pd.read_csv('outputtotal2_3fps.csv')
x = df.iloc[:, 1:]
y = df.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
neigh = KNeighborsClassifier(n_neighbors=8)
neigh.fit(x_train, y_train)
score = neigh.score(x_test, y_test)
print("準確率:{}".format(score))
df_test = pd.read_csv('output0_2.csv')
x = df_test.iloc[:, 1:]
y = df_test.iloc[:, 0]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.9)
score = neigh.score(x_test, y_test)
print("準確率:{}".format(score))
print(type(score))
# Out:
# 準確率:0.8942652329749103
# 準確率:0.5349442379182157
# <class 'numpy.float64'>
