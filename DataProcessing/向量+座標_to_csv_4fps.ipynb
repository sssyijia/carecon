# %%
import os
import numpy as np
import tensorflow as tf
import os
import csv
import cv2 as cv
import mediapipe as mp
import pandas as pd

# %%
dir_path = os.path.abspath(os.path.dirname("__file__"))
dir_list = os.listdir(dir_path)
print(dir_list)
# Out:
# ['.ipynb_checkpoints', '101.mp4', '1012.mp4', '117.mp4', '1172.mp4', '120.mp4', '1202.mp4', '1222.mp4', '122b.mp4', '127.mp4', '129.mp4', '201.mp4', '2012.mp4', '217.mp4', '2172.mp4', '220.mp4', '2202.mp4', '222.mp4', '2222.mp4', '227.mp4', '229.mp4', '301.mp4', '3012.mp4', '317.mp4', '3172.mp4', '320.mp4', '3202.mp4', '322.mp4', '3222.mp4', '327.mp4', '329.mp4', '401.mp4', '4012.mp4', '417.mp4', '4172.mp4', '420.mp4', '4202.mp4', '422.mp4', '4222.mp4', '427.mp4', '429.mp4', '501.mp4', '5012.mp4', '517.mp4', '5172.mp4', '520.mp4', '5202.mp4', '522.mp4', '5222.mp4', '527.mp4', '529.mp4', '601 (1).mp4', '601.mp4', '6012.mp4', '617.mp4', '6172.mp4', '620.mp4', '6202.mp4', '622.mp4', '6222.mp4', '627.mp4', '629.mp4', '701.mp4', '7012.mp4', '717.mp4', '7172.mp4', '720.mp4', '7202.mp4', '722.mp4', '7222.mp4', '727.mp4', '729.mp4', '801.mp4', '8012.mp4', '817.mp4', '8172.mp4', '820.mp4', '8202.mp4', '8222.mp4', '822b.mp4', '827.mp4', '829.mp4', 'CV1220_2fps.csv', 'fps_Vec_1220.csv', 'landmark1_to_csv_os-Copy1.ipynb', 'landmark1_to_csv_os.ipynb', 'landmark_to_csv_os.ipynb', 'outputnew0.csv', 'outputnew1_2fps.csv', 'test_data']

# %%
df2 = pd.DataFrame(columns=["class","thumb_CmcX","thumb_CmcY","thumb_CmcZ","thumb_McpX","thumb_McpY","thumb_McpZ","thumb_IpX","thumb_IpY","thumb_IpZ","thumb_TipX","thumb_TipY","thumb_TipZ","index_McpX","index_McpY","index_McpZ","index_PipX","index_PipY","index_PipZ","index_DipX","index_DipY","index_DipZ","index_TipX","index_TipY","index_TipZ","middle_McpX","middle_McpY","middle_McpZ","middle_PipX","middle_PipY","middle_PipZ","middle_DipX","middle_DipY","middle_DipZ","middle_TipX","middle_TipY","middle_TipZ","ring_McpX","ring_McpY","ring_McpZ","ring_PipX","ring_PipY","ring_PipZ","ring_DipX","ring_DipY","ring_DipZ","ring_TipX","ring_TipY","ring_TipZ","pinky_McpX","pinky_McpY","pinky_McpZ","pinky_PipX","pinky_PipY","pinky_PipZ","pinky_DipX","pinky_DipY","pinky_DipZ","pinky_TipX","pinky_TipY","pinky_TipZ","wristX","wristY","wristZ","thumbCmcX","thumbCmcY","thumbCmcZ","thumbMcpX","thumbMcpY","thumbMcpZ","thumbIpX","thumbIpY","thumbIpZ","thumbTipX","thumbTipY","thumbTipZ","indexMcpX","indexMcpY","indexMcpZ","indexPipX","indexPipY","indexPipZ","indexDipX","indexDipY","indexDipZ","indexTipX","indexTipY","indexTipZ","middleMcpX","middleMcpY","middleMcpZ","middlePipX","middlePipY","middlePipZ","middleDipX","middleDipY","middleDipZ","middleTipX","middleTipY","middleTipZ","ringMcpX","ringMcpY","ringMcpZ","ringPipX","ringPipY","ringPipZ","ringDipX","ringDipY","ringDipZ","ringTipX","ringTipY","ringTipZ","pinkyMcpX","pinkyMcpY","pinkyMcpZ","pinkyPipX","pinkyPipY","pinkyPipZ","pinkyDipX","pinkyDipY","pinkyDipZ","pinkyTipX","pinkyTipY","pinkyTipZ"])

mp_hands = mp.solutions.hands    # mediapipe 偵測手掌方法
mp_drawing = mp.solutions.drawing_utils    # mediapipe 繪圖方法
mp_drawing_styles = mp.solutions.drawing_styles    # mediapipe 繪圖樣式

# %%
df2
# Out:
# Empty DataFrame
# Columns: [class, thumb_CmcX, thumb_CmcY, thumb_CmcZ, thumb_McpX, thumb_McpY, thumb_McpZ, thumb_IpX, thumb_IpY, thumb_IpZ, thumb_TipX, thumb_TipY, thumb_TipZ, index_McpX, index_McpY, index_McpZ, index_PipX, index_PipY, index_PipZ, index_DipX, index_DipY, index_DipZ, index_TipX, index_TipY, index_TipZ, middle_McpX, middle_McpY, middle_McpZ, middle_PipX, middle_PipY, middle_PipZ, middle_DipX, middle_DipY, middle_DipZ, middle_TipX, middle_TipY, middle_TipZ, ring_McpX, ring_McpY, ring_McpZ, ring_PipX, ring_PipY, ring_PipZ, ring_DipX, ring_DipY, ring_DipZ, ring_TipX, ring_TipY, ring_TipZ, pinky_McpX, pinky_McpY, pinky_McpZ, pinky_PipX, pinky_PipY, pinky_PipZ, pinky_DipX, pinky_DipY, pinky_DipZ, pinky_TipX, pinky_TipY, pinky_TipZ, wristX, wristY, wristZ, thumbCmcX, thumbCmcY, thumbCmcZ, thumbMcpX, thumbMcpY, thumbMcpZ, thumbIpX, thumbIpY, thumbIpZ, thumbTipX, thumbTipY, thumbTipZ, indexMcpX, indexMcpY, indexMcpZ, indexPipX, indexPipY, indexPipZ, indexDipX, indexDipY, indexDipZ, indexTipX, indexTipY, indexTipZ, middleMcpX, middleMcpY, middleMcpZ, middlePipX, middlePipY, middlePipZ, middleDipX, middleDipY, middleDipZ, middleTipX, middleTipY, middleTipZ, ...]
# Index: []
#
# [0 rows x 124 columns]

# %%
for file in dir_list:
    if file[0] not in ['0','1','2','3','4','5','6','7','8']:
        continue
    cap = cv.VideoCapture(file)
    count1 = 0
    posture = file[0]
    if posture == "1":
        subclass = "0"
    elif posture == "2":
        subclass = "1"
    elif posture == "3" or posture == "4":
        subclass = "2"
    elif posture == "5" or posture == "7":
        subclass = "3"
    elif posture == "6" or posture == "8":
        subclass = "4"

    with mp_hands.Hands(max_num_hands=1, model_complexity=1, min_detection_confidence=0.3, min_tracking_confidence=0.3) as hands:
        if not cap.isOpened():
            print("Cannot open camera")
            exit()
        while True:
            # if count1 >= 150:
            #     break
            ret, image = cap.read()
            if not ret:
                print("Cannot receive frame")
                print(file)
                break
            if count1 <= 7:
                count1 += 1
                continue
            results = hands.process(cv.flip(cv.cvtColor(image, cv.COLOR_BGR2RGB), 1))
            image_height, image_width, _ = image.shape

            # Draw hand landmarks
            annotated_image = cv.flip(image.copy(), 1)
            if results.multi_hand_landmarks != None:
                for hand_landmarks in results.multi_hand_landmarks:
                    wristX = hand_landmarks.landmark[mp_hands.HandLandmark.WRIST].x
                    wristY = hand_landmarks.landmark[mp_hands.HandLandmark.WRIST].y
                    wristZ = hand_landmarks.landmark[mp_hands.HandLandmark.WRIST].z
                    thumb_CmcX = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_CMC].x 
                    thumb_CmcY = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_CMC].y 
                    thumb_CmcZ = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_CMC].z
                    thumb_McpX = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_MCP].x 
                    thumb_McpY = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_MCP].y
                    thumb_McpZ = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_MCP].z
                    thumb_IpX = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_IP].x 
                    thumb_IpY = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_IP].y 
                    thumb_IpZ = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_IP].z 
                    thumb_TipX = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP].x 
                    thumb_TipY = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP].y 
                    thumb_TipZ = hand_landmarks.landmark[mp_hands.HandLandmark.THUMB_TIP].z 
                    index_McpX = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP].x 
                    index_McpY = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP].y 
                    index_McpZ = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_MCP].z 
                    index_PipX = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_PIP].x
                    index_PipY = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_PIP].y 
                    index_PipZ = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_PIP].z 
                    index_DipX = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_DIP].x
                    index_DipY = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_DIP].y
                    index_DipZ = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_DIP].z 
                    index_TipX = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].x 
                    index_TipY = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].y 
                    index_TipZ = hand_landmarks.landmark[mp_hands.HandLandmark.INDEX_FINGER_TIP].z 
                    middle_McpX = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_MCP].x 
                    middle_McpY = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_MCP].y 
                    middle_McpZ = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_MCP].z 
                    middle_PipX = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_PIP].x 
                    middle_PipY = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_PIP].y 
                    middle_PipZ = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_PIP].z 
                    middle_DipX = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_DIP].x 
                    middle_DipY = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_DIP].y 
                    middle_DipZ = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_DIP].z 
                    middle_TipX = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP].x
                    middle_TipY = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP].y
                    middle_TipZ = hand_landmarks.landmark[mp_hands.HandLandmark.MIDDLE_FINGER_TIP].z
                    ring_McpX = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_MCP].x
                    ring_McpY = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_MCP].y
                    ring_McpZ = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_MCP].z
                    ring_PipX = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_PIP].x 
                    ring_PipY = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_PIP].y 
                    ring_PipZ = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_PIP].z
                    ring_DipX = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_DIP].x 
                    ring_DipY = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_DIP].y 
                    ring_DipZ = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_DIP].z 
                    ring_TipX = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP].x 
                    ring_TipY = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP].y 
                    ring_TipZ = hand_landmarks.landmark[mp_hands.HandLandmark.RING_FINGER_TIP].z
                    pinky_McpX = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_MCP].x 
                    pinky_McpY = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_MCP].y 
                    pinky_McpZ = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_MCP].z 
                    pinky_PipX = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_PIP].x 
                    pinky_PipY = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_PIP].y 
                    pinky_PipZ = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_PIP].z 
                    pinky_DipX = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_DIP].x 
                    pinky_DipY = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_DIP].y 
                    pinky_DipZ = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_DIP].z 
                    pinky_TipX = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP].x 
                    pinky_TipY = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP].y 
                    pinky_TipZ = hand_landmarks.landmark[mp_hands.HandLandmark.PINKY_TIP].z 

                    # 後節點減去前節點座標
                    df = pd.DataFrame({"class" : subclass,
                    # Thumb Finger
                    "thumb_CmcX" : thumb_CmcX - wristX,
                    "thumb_CmcY" : thumb_CmcY - wristY,
                    "thumb_CmcZ" : thumb_CmcZ - wristZ,

                    "thumb_McpX" : thumb_McpX - thumb_CmcX,
                    "thumb_McpY" : thumb_McpY - thumb_CmcY,
                    "thumb_McpZ" : thumb_McpZ - thumb_CmcZ,

                    "thumb_IpX" : thumb_IpX - thumb_McpX,
                    "thumb_IpY" : thumb_IpY - thumb_McpY,
                    "thumb_IpZ" : thumb_IpZ - thumb_McpZ,

                    "thumb_TipX" : thumb_TipX - thumb_IpX,
                    "thumb_TipY" : thumb_TipY - thumb_IpY,
                    "thumb_TipZ" : thumb_TipZ - thumb_IpZ,
                    # Index Finger
                    "index_McpX" : index_McpX - wristX,
                    "index_McpY" : index_McpY - wristY,
                    "index_McpZ" : index_McpZ - wristZ,

                    "index_PipX" : index_PipX - index_McpX,
                    "index_PipY" : index_PipY - index_McpY,
                    "index_PipZ" : index_PipZ - index_McpZ,

                    "index_DipX" : index_DipX - index_PipX,
                    "index_DipY" : index_DipY - index_PipY,
                    "index_DipZ" : index_DipZ - index_PipZ,

                    "index_TipX" : index_TipX - index_DipX,
                    "index_TipY" : index_TipY - index_DipY,
                    "index_TipZ" : index_TipZ - index_DipZ,
                    # Middle Finger
                    "middle_McpX" : middle_McpX - index_McpX,
                    "middle_McpY" : middle_McpY - index_McpY,
                    "middle_McpZ" : middle_McpZ - index_McpZ,

                    "middle_PipX" : middle_PipX - middle_McpX,
                    "middle_PipY" : middle_PipX - middle_McpY,
                    "middle_PipZ" : middle_PipX - middle_McpZ,

                    "middle_DipX" : middle_DipX - middle_PipX,
                    "middle_DipY" : middle_DipY - middle_PipY,
                    "middle_DipZ" : middle_DipZ - middle_PipZ,

                    "middle_TipX" : middle_TipX - middle_DipX,
                    "middle_TipY" : middle_TipY - middle_DipY,
                    "middle_TipZ" : middle_TipZ - middle_DipZ,
                    # Ring Finger
                    "ring_McpX": ring_McpX - middle_McpX,
                    "ring_McpY": ring_McpY - middle_McpY,
                    "ring_McpZ": ring_McpZ - middle_McpZ,

                    "ring_PipX": ring_PipX - ring_McpX,
                    "ring_PipY": ring_PipY - ring_McpY,
                    "ring_PipZ": ring_PipZ - ring_McpZ,

                    "ring_DipX": ring_DipX - ring_PipX,
                    "ring_DipY": ring_DipY - ring_PipY,
                    "ring_DipZ": ring_DipZ - ring_PipZ,

                    "ring_TipX": ring_TipX - ring_DipX,
                    "ring_TipY": ring_TipY - ring_DipY,
                    "ring_TipZ": ring_TipZ - ring_DipZ,
                    # Pinky Finger
                    "pinky_McpX" : pinky_McpX - wristX,
                    "pinky_McpY" : pinky_McpY - wristY,
                    "pinky_McpZ" : pinky_McpZ - wristZ,

                    "pinky_PipX" : pinky_PipX - pinky_McpX,
                    "pinky_PipY" : pinky_PipY - pinky_McpY,
                    "pinky_PipZ" : pinky_PipZ - pinky_McpZ,

                    "pinky_DipX" : pinky_DipX - pinky_PipX,
                    "pinky_DipY" : pinky_DipY - pinky_PipY,
                    "pinky_DipZ" : pinky_DipZ - pinky_PipZ,

                    "pinky_TipX" : pinky_TipX - pinky_DipX,
                    "pinky_TipY" : pinky_TipY - pinky_DipY,
                    "pinky_TipZ" : pinky_TipZ - pinky_DipZ,
                                       
                    "wristX" : wristX,
                    "wristY" : wristY,
                    "wristZ" : wristZ,
                    # Thumb Finger
                    "thumbCmcX" : thumb_CmcX,
                    "thumbCmcY" : thumb_CmcY,
                    "thumbCmcZ" : thumb_CmcZ,

                    "thumbMcpX" : thumb_McpX,
                    "thumbMcpY" : thumb_McpY,
                    "thumbMcpZ" : thumb_McpZ,

                    "thumbIpX": thumb_IpX,
                    "thumbIpY": thumb_IpY,
                    "thumbIpZ": thumb_IpZ,

                    "thumbTipX" : thumb_TipX,
                    "thumbTipY" : thumb_TipY,
                    "thumbTipZ" : thumb_TipZ,
                    # Index Finger
                    "indexMcpX" : index_McpX,
                    "indexMcpY" : index_McpY,
                    "indexMcpZ" : index_McpZ,

                    "indexPipX" : index_PipX,
                    "indexPipY" : index_PipY,
                    "indexPipZ" : index_PipZ,

                    "indexDipX" : index_DipX,
                    "indexDipY" : index_DipY,
                    "indexDipZ" : index_DipZ,

                    "indexTipX" : index_TipX,
                    "indexTipY" : index_TipY,
                    "indexTipZ" : index_TipZ,
                    # Midde Finger
                    "middleMcpX" : middle_McpX,
                    "middleMcpY" : middle_McpY,
                    "middleMcpZ" : middle_McpZ,

                    "middlePipX" : middle_PipX,
                    "middlePipY" : middle_PipX,
                    "middlePipZ" : middle_PipX,

                    "middleDipX" : middle_DipX,
                    "middleDipY" : middle_DipY,
                    "middleDipZ" : middle_DipZ,

                    "middleTipX" : middle_TipX,
                    "middleTipY" : middle_TipY,
                    "middleTipZ" : middle_TipZ,
                    # Ring Finger
                    "ringMcpX": ring_McpX,
                    "ringMcpY": ring_McpY,
                    "ringMcpZ": ring_McpZ,

                    "ringPipX": ring_PipX,
                    "ringPipY": ring_PipY,
                    "ringPipZ": ring_PipZ,

                    "ringDipX": ring_DipX,
                    "ringDipY": ring_DipY,
                    "ringDipZ": ring_DipZ,

                    "ringTipX": ring_TipX,
                    "ringTipY": ring_TipY,
                    "ringTipZ": ring_TipZ,
                    # Pinky Finger
                    "pinkyMcpX" : pinky_McpX,
                    "pinkyMcpY" : pinky_McpY,
                    "pinkyMcpZ" : pinky_McpZ,

                    "pinkyPipX" : pinky_PipX,
                    "pinkyPipY" : pinky_PipY,
                    "pinkyPipZ" : pinky_PipZ,

                    "pinkyDipX" : pinky_DipX,
                    "pinkyDipY" : pinky_DipY,
                    "pinkyDipZ" : pinky_DipZ,

                    "pinkyTipX" : pinky_TipX,
                    "pinkyTipY" : pinky_TipY,
                    "pinkyTipZ" : pinky_TipZ}, index=[count1])
                    df2 = pd.concat([df2, df], ignore_index=True)
                count1 = 0

                    # Draw the Skeleton
                    # mp_drawing.draw_landmarks(annotated_image, hand_landmarks, mp_hands.HAND_CONNECTIONS)

cap.release()
cv.destroyAllWindows()
# Out:
# Cannot receive frame
# 101.mp4
# Cannot receive frame
# 1012.mp4
# Cannot receive frame
# 117.mp4
# Cannot receive frame
# 1172.mp4
# Cannot receive frame
# 120.mp4
# Cannot receive frame
# 1202.mp4
# Cannot receive frame
# 1222.mp4
# Cannot receive frame
# 122b.mp4
# Cannot receive frame
# 127.mp4
# Cannot receive frame
# 129.mp4
# Cannot receive frame
# 201.mp4
# Cannot receive frame
# 2012.mp4
# Cannot receive frame
# 217.mp4
# Cannot receive frame
# 2172.mp4
# Cannot receive frame
# 220.mp4
# Cannot receive frame
# 2202.mp4
# Cannot receive frame
# 222.mp4
# Cannot receive frame
# 2222.mp4
# Cannot receive frame
# 227.mp4
# Cannot receive frame
# 229.mp4
# Cannot receive frame
# 301.mp4
# Cannot receive frame
# 3012.mp4
# Cannot receive frame
# 317.mp4
# Cannot receive frame
# 3172.mp4
# Cannot receive frame
# 320.mp4
# Cannot receive frame
# 3202.mp4
# Cannot receive frame
# 322.mp4
# Cannot receive frame
# 3222.mp4
# Cannot receive frame
# 327.mp4
# Cannot receive frame
# 329.mp4
# Cannot receive frame
# 401.mp4
# Cannot receive frame
# 4012.mp4
# Cannot receive frame
# 417.mp4
# Cannot receive frame
# 4172.mp4
# Cannot receive frame
# 420.mp4
# Cannot receive frame
# 4202.mp4
# Cannot receive frame
# 422.mp4
# Cannot receive frame
# 4222.mp4
# Cannot receive frame
# 427.mp4
# Cannot receive frame
# 429.mp4
# Cannot receive frame
# 501.mp4
# Cannot receive frame
# 5012.mp4
# Cannot receive frame
# 517.mp4
# Cannot receive frame
# 5172.mp4
# Cannot receive frame
# 520.mp4
# Cannot receive frame
# 5202.mp4
# Cannot receive frame
# 522.mp4
# Cannot receive frame
# 5222.mp4
# Cannot receive frame
# 527.mp4
# Cannot receive frame
# 529.mp4
# Cannot receive frame
# 601 (1).mp4
# Cannot receive frame
# 601.mp4
# Cannot receive frame
# 6012.mp4
# Cannot receive frame
# 617.mp4
# Cannot receive frame
# 6172.mp4
# Cannot receive frame
# 620.mp4
# Cannot receive frame
# 6202.mp4
# Cannot receive frame
# 622.mp4
# Cannot receive frame
# 6222.mp4
# Cannot receive frame
# 627.mp4
# Cannot receive frame
# 629.mp4
# Cannot receive frame
# 701.mp4
# Cannot receive frame
# 7012.mp4
# Cannot receive frame
# 717.mp4
# Cannot receive frame
# 7172.mp4
# Cannot receive frame
# 720.mp4
# Cannot receive frame
# 7202.mp4
# Cannot receive frame
# 722.mp4
# Cannot receive frame
# 7222.mp4
# Cannot receive frame
# 727.mp4
# Cannot receive frame
# 729.mp4
# Cannot receive frame
# 801.mp4
# Cannot receive frame
# 8012.mp4
# Cannot receive frame
# 817.mp4
# Cannot receive frame
# 8172.mp4
# Cannot receive frame
# 820.mp4
# Cannot receive frame
# 8202.mp4
# Cannot receive frame
# 8222.mp4
# Cannot receive frame
# 822b.mp4
# Cannot receive frame
# 827.mp4
# Cannot receive frame
# 829.mp4

# %%
df2
# Out:
#       class thumb_CmcX thumb_CmcY thumb_CmcZ thumb_McpX thumb_McpY thumb_McpZ  \
# 0         0  -0.037934  -0.135734  -0.029992  -0.131812  -0.103565  -0.035802
# 1         0  -0.114241  -0.104417   0.017464  -0.135644  -0.075367  -0.011286
# 2         0   -0.04958  -0.139465  -0.013207  -0.127821  -0.100481  -0.035286
# 3         0   -0.06934  -0.148411  -0.050017  -0.136559  -0.093726  -0.043039
# 4         0  -0.069364   -0.12478  -0.057598  -0.134393  -0.086255  -0.044693
# ...     ...        ...        ...        ...        ...        ...        ...
# 12295     4   0.089943   0.042216   -0.11311   0.143644   0.021051  -0.018306
# 12296     4   0.088263   0.044141  -0.118323   0.141474   0.020553  -0.016949
# 12297     4   0.068015   0.048818  -0.102059   0.143783   0.017532  -0.022306
# 12298     4   0.074052  -0.002119  -0.127045   0.118551   0.002106  -0.027475
# 12299     4   0.079379   0.007421  -0.115003   0.124837   0.008892  -0.023844
#
#       thumb_IpX thumb_IpY thumb_IpZ  ... pinkyMcpZ pinkyPipX pinkyPipY  \
# 0     -0.131532 -0.004144  -0.02144  ... -0.161485  0.477003  0.479559
# 1     -0.121081 -0.007918 -0.012632  ... -0.122128  0.397907  0.413768
# 2     -0.128353 -0.021666 -0.027473  ...  -0.17428  0.346279  0.499957
# 3     -0.123627 -0.003975 -0.022738  ...  -0.13307  0.280744  0.589877
# 4     -0.127978 -0.007434 -0.021676  ... -0.138025  0.295417  0.591278
# ...         ...       ...       ...  ...       ...       ...       ...
# 12295  0.127303  0.017189   0.00651  ...  0.093212   0.63771  0.717911
# 12296  0.124965  0.015766  0.009737  ...  0.099575  0.617393  0.697525
# 12297  0.132501   0.01161 -0.001678  ...  0.047385  0.619208  0.712489
# 12298  0.128922  0.034982 -0.002067  ...  0.114072   0.63213  0.875505
# 12299  0.130577  0.022519 -0.003378  ...   0.09138   0.61153  0.866635
#
#       pinkyPipZ pinkyDipX pinkyDipY pinkyDipZ pinkyTipX pinkyTipY pinkyTipZ
# 0      -0.16758   0.50637  0.449541 -0.139577  0.557347  0.455201 -0.121038
# 1      -0.14139  0.426654   0.40601 -0.122197  0.483216  0.391172 -0.105563
# 2     -0.184182  0.386953  0.484769 -0.154152   0.44511  0.498989  -0.13514
# 3     -0.132249  0.316329  0.566178 -0.111297   0.35883  0.579892 -0.101315
# 4     -0.146137  0.328651  0.564698  -0.12713  0.371691  0.581976 -0.116987
# ...         ...       ...       ...       ...       ...       ...       ...
# 12295  0.054848  0.602067  0.780754  0.037837   0.54541  0.797443   0.03833
# 12296  0.055763  0.587921   0.76431   0.03201  0.528785  0.788365  0.028649
# 12297  0.003777  0.586416  0.781389  -0.01027  0.530773  0.804655 -0.010331
# 12298  0.081096  0.598468  0.923126  0.055911   0.54196  0.936775  0.046546
# 12299  0.044885  0.566592   0.91603  0.026292  0.507378  0.924343  0.027965
#
# [12300 rows x 124 columns]

# %%
df2.to_csv("CV_4fps_1226.csv", index=False)
